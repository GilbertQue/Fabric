# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!

# Get all Datasets
import sempy.fabric as fabric
from pyspark.sql.functions import current_timestamp
from datetime import datetime,date,timedelta
from pyspark.sql import SparkSession
from pyspark.sql.functions import lit

# Getting All the datasets
x = fabric.list_datasets()

#Convert from Pandas to Spark Data Frame
spk_datasets = spark.createDataFrame(x)

# Adding the Current Date Time Column
spk_datasets = spk_datasets.withColumn("CurrentDateTime", lit(current_timestamp()))

#Display Data Frame
display(spk_datasets)
